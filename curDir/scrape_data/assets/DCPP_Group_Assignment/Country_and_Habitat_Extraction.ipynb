# %%
import pycountry
import pandas as pd
import numpy as np
import wikipedia

# %%
birds_df = pd.read_excel('bird_K.xlsx', sheet_name = 'Sheet1')
birds_df.head()
# Out:
#    Unnamed: 0                    Name            Conservation status  \
# 0           1          Kadavu fantail  Near Threatened (IUCN 3.1)[1]
# 1           2       Kadavu honeyeater    Least Concern (IUCN 3.1)[1]
# 2           3  Kaempfer's tody-tyrant       Vulnerable (IUCN 3.1)[1]
# 3           4   Kaempfer's woodpecker       Vulnerable (IUCN 3.1)[1]
# 4           6       Kakamega greenbul                            NaN
#
#     Kingdom    Phylum Class          Order        Family  \
# 0  Animalia  Chordata  Aves  Passeriformes  Rhipiduridae
# 1  Animalia  Chordata  Aves  Passeriformes  Meliphagidae
# 2  Animalia  Chordata  Aves  Passeriformes    Tyrannidae
# 3  Animalia  Chordata  Aves     Piciformes       Picidae
# 4  Animalia  Chordata  Aves  Passeriformes  Pycnonotidae
#
#                        Genus        Species  \
# 0                  Rhipidura   R. personata
# 1  MeliphacatorMathews, 1930  M. provocator
# 2                Hemitriccus   H. kaempferi
# 3                     Celeus     C. obrieni
# 4              Arizelocichla   A. kakamegae
#
#                               Binomial Name  \
# 0      Rhipidura personataE.P. Ramsay, 1876
# 1  Meliphacator provocator(Layard EL, 1875)
# 2       Hemitriccus kaempferi(Zimmer, 1953)
# 3               Celeus obrieni(Short, 1973)
# 4     Arizelocichla kakamegae(Sharpe, 1900)
#
#                                             Synonyms  \
# 0                                                NaN
# 1                               Xanthotis provocator
# 2                                                NaN
# 3                                                NaN
# 4  Andropadus kakamegae Arizelocichla masukuensis...
#
#                                              Summary  \
# 0  The Kadavu fantail (Rhipidura personata) is a ...
# 1  The Kadavu honeyeater (Meliphacator provocator...
# 2  Kaempfer's tody-tyrant (Hemitriccus kaempferi)...
# 3  Kaempfer's woodpecker (Celeus obrieni), also k...
# 4  Kakamega greenbul (Arizelocichla kakamegae), i...
#
#                                           Categories  \
# 0  ['All stub articles', "Articles with 'species'...
# 1  ['All stub articles', "Articles with 'species'...
# 2  ['All stub articles', "Articles with 'species'...
# 3  ["Articles with 'species' microformats", 'Arti...
# 4  ['All stub articles', 'Arizelocichla', "Articl...
#
#                                           References  \
# 0  ['http://datazone.birdlife.org/species/factshe...
# 1  ['http://www.worldtwitch.com/fiji.htm', 'http:...
# 2  ['http://www.gpo.gov/fdsys/pkg/FR-2010-12-28/p...
# 3  ['http://datazone.birdlife.org/species/factshe...
# 4  ['http://www.worldbirdnames.org/bow/bulbuls/',...
#
#                                             Wiki URL  \
# 0       https://en.wikipedia.org/wiki/Kadavu_fantail
# 1    https://en.wikipedia.org/wiki/Kadavu_honeyeater
# 2  https://en.wikipedia.org/wiki/Kaempfer%27s_tod...
# 3  https://en.wikipedia.org/wiki/Kaempfer%27s_woo...
# 4    https://en.wikipedia.org/wiki/Kakamega_greenbul
#
#                                                Image
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
birds_df['Countries'] = np.NaN
birds_df['Habitat'] = np.NaN

# %%
for i in range(0, len(birds_df)):
    name = birds_df.Name[i]
    summary = wikipedia.summary(name)
    birds_df.Countries[i] = findCountry(summary)
    birds_df.Habitat[i] = findHabitat(summary)
# Out:
# <ipython-input-67-63f18dc35a6d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Countries[i] = findCountry(summary)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-67-63f18dc35a6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Habitat[i] = findHabitat(summary)

# %%
def findCountry(data):
    countries = sorted([country.name for country in pycountry.countries] , key=lambda x: -len(x))
    for country in countries:
        if country.lower() in data.lower():
            return country
    return None

# %%
#habitat
habitats_list = ['forest', 'forests', 'woods', 'woods', 'woodland', 'woodlands', 'bog', 'bogs', 'fen', 'fens', 'marsh', 'marshes', 'swamp', 'swamps', 'wetland', 'grasslands', 'prairie', 'scrubs','shrubs', 'backyards']

# %%
def findHabitat(data):
    for habitat in habitats_list:
        if habitat in data.lower():
            return habitat
    return None

# %%
birds_df.head(20)
# Out:
#     Unnamed: 0                    Name            Conservation status  \
# 0            1          Kadavu fantail  Near Threatened (IUCN 3.1)[1]
# 1            2       Kadavu honeyeater    Least Concern (IUCN 3.1)[1]
# 2            3  Kaempfer's tody-tyrant       Vulnerable (IUCN 3.1)[1]
# 3            4   Kaempfer's woodpecker       Vulnerable (IUCN 3.1)[1]
# 4            6       Kakamega greenbul                            NaN
# 5            7               Kākāwahie   Extinct (1963) (IUCN 3.1)[1]
# 6            8    Kalahari scrub robin    Least Concern (IUCN 3.1)[1]
# 7            9          Kalij pheasant    Least Concern (IUCN 3.1)[1]
# 8           11     Kalkadoon grasswren    Least Concern (IUCN 3.1)[1]
# 9           12                  Kāmaʻo   Extinct (1989) (IUCN 3.1)[1]
# 10          14         Kandt's waxbill       Least Concern (IUCN 3.1)
# 11          16              Karoo chat    Least Concern (IUCN 3.1)[1]
# 12          17         Karoo eremomela    Least Concern (IUCN 3.1)[1]
# 13          18           Karoo korhaan    Least Concern (IUCN 3.1)[1]
# 14          19              Karoo lark    Least Concern (IUCN 3.1)[1]
# 15          20  Karoo long-billed lark    Least Concern (IUCN 3.1)[1]
# 16          21            Karoo prinia    Least Concern (IUCN 3.1)[1]
# 17          22       Karoo scrub robin       Least Concern (IUCN 3.1)
# 18          23            Karoo thrush    Least Concern (IUCN 3.1)[1]
# 19          26      Kashmir flycatcher       Vulnerable (IUCN 3.1)[1]
#
#      Kingdom    Phylum Class          Order        Family  \
# 0   Animalia  Chordata  Aves  Passeriformes  Rhipiduridae
# 1   Animalia  Chordata  Aves  Passeriformes  Meliphagidae
# 2   Animalia  Chordata  Aves  Passeriformes    Tyrannidae
# 3   Animalia  Chordata  Aves     Piciformes       Picidae
# 4   Animalia  Chordata  Aves  Passeriformes  Pycnonotidae
# 5   Animalia  Chordata  Aves  Passeriformes  Fringillidae
# 6   Animalia  Chordata  Aves  Passeriformes  Muscicapidae
# 7   Animalia  Chordata  Aves    Galliformes   Phasianidae
# 8   Animalia  Chordata  Aves  Passeriformes     Maluridae
# 9   Animalia  Chordata  Aves  Passeriformes      Turdidae
# 10  Animalia  Chordata  Aves  Passeriformes   Estrildidae
# 11  Animalia  Chordata  Aves  Passeriformes  Muscicapidae
# 12  Animalia  Chordata  Aves  Passeriformes  Cisticolidae
# 13  Animalia  Chordata  Aves    Otidiformes      Otididae
# 14  Animalia  Chordata  Aves  Passeriformes     Alaudidae
# 15  Animalia  Chordata  Aves  Passeriformes     Alaudidae
# 16  Animalia  Chordata  Aves  Passeriformes  Cisticolidae
# 17  Animalia  Chordata  Aves  Passeriformes  Muscicapidae
# 18  Animalia  Chordata  Aves  Passeriformes      Turdidae
# 19  Animalia  Chordata  Aves  Passeriformes  Muscicapidae
#
#                         Genus          Species  \
# 0                   Rhipidura     R. personata
# 1   MeliphacatorMathews, 1930    M. provocator
# 2                 Hemitriccus     H. kaempferi
# 3                      Celeus       C. obrieni
# 4               Arizelocichla     A. kakamegae
# 5                 Paroreomyza      †P. flammea
# 6                Cercotrichas         C. paena
# 7                     Lophura  L. leucomelanos
# 8                   Amytornis      A. ballarae
# 9                   Myadestes  †M. myadestinus
# 10                   Estrilda        E. kandti
# 11                 Emarginata    E. schlegelii
# 12                  Eremomela      E. gregalis
# 13                  Eupodotis      E. vigorsii
# 14               Calendulauda     C. albescens
# 15                Certhilauda   C. subcoronata
# 16                     Prinia      P. maculosa
# 17               Cercotrichas    C. coryphaeus
# 18                     Turdus        T. smithi
# 19                   Ficedula      F. subrubra
#
#                                      Binomial Name  \
# 0             Rhipidura personataE.P. Ramsay, 1876
# 1         Meliphacator provocator(Layard EL, 1875)
# 2              Hemitriccus kaempferi(Zimmer, 1953)
# 3                      Celeus obrieni(Short, 1973)
# 4            Arizelocichla kakamegae(Sharpe, 1900)
# 5               †Paroreomyza flammea(Wilson, 1889)
# 6                    Cercotrichas paenaSmith, 1836
# 7               Lophura leucomelanos(Latham, 1790)
# 8                   Amytornis ballaraeCondon, 1969
# 9          †Myadestes myadestinus(Stejneger, 1887)
# 10                  Estrilda kandtiReichenow, 1902
# 11           Emarginata schlegelii(Wahlberg, 1855)
# 12                   Eremomela gregalisSmith, 1829
# 13                 Eupodotis vigorsii(Smith, 1831)
# 14        Calendulauda albescens(Lafresnaye, 1839)
# 15              Certhilauda subcoronataSmith, 1843
# 16                 Prinia maculosa(Boddaert, 1783)
# 17         Cercotrichas coryphaeus(Vieillot, 1817)
# 18                    Turdus smithiBonaparte, 1850
# 19  Ficedula subrubra(Hartert & Steinbacher, 1934)
#
#                                              Synonyms  \
# 0                                                 NaN
# 1                                Xanthotis provocator
# 2                                                 NaN
# 3                                                 NaN
# 4   Andropadus kakamegae Arizelocichla masukuensis...
# 5                                                 NaN
# 6                                 Erythropyggia paena
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                               Cercomela schlegelii
# 12                                                NaN
# 13                              Heterotetrax vigorsii
# 14  Alauda albescens Certhilauda albescens Mirafra...
# 15                                                NaN
# 16                                                NaN
# 17                            Erythropygia coryphaeus
# 18                                                NaN
# 19                                                NaN
#
#                                               Summary  \
# 0   The Kadavu fantail (Rhipidura personata) is a ...
# 1   The Kadavu honeyeater (Meliphacator provocator...
# 2   Kaempfer's tody-tyrant (Hemitriccus kaempferi)...
# 3   Kaempfer's woodpecker (Celeus obrieni), also k...
# 4   Kakamega greenbul (Arizelocichla kakamegae), i...
# 5   The kākāwahie or Molokaʻi creeper (Paroreomyza...
# 6   The Kalahari scrub robin (Cercotricha paena) i...
# 7   The kalij pheasant (Lophura leucomelanos) is a...
# 8   The Kalkadoon grasswren (Amytornis ballarae), ...
# 9   The kāmaʻo or large Kauaʻi thrush (Myadestes m...
# 10  Kandt's waxbill (Estrilda kandti) is a species...
# 11  The Karoo chat (Emarginata schlegelii) is a sm...
# 12  The Karoo eremomela (Eremomela gregalis), also...
# 13  The karoo korhaan (Eupodotis vigorsii), also k...
# 14  The Karoo lark should not be confused with the...
# 15  Larks are passerine birds of the family Alaudi...
# 16  The Karoo prinia or  spotted prinia (Prinia ma...
# 17  The Karoo scrub robin (Cercotrichas coryphaeus...
# 18  The Karoo thrush (Turdus smithi) also known as...
# 19  The Kashmir flycatcher (Ficedula subrubra) is ...
#
#                                            Categories  \
# 0   ['All stub articles', "Articles with 'species'...
# 1   ['All stub articles', "Articles with 'species'...
# 2   ['All stub articles', "Articles with 'species'...
# 3   ["Articles with 'species' microformats", 'Arti...
# 4   ['All stub articles', 'Arizelocichla', "Articl...
# 5   ['All articles needing additional references',...
# 6   ["Articles with 'species' microformats", 'Arti...
# 7   ["Articles with 'species' microformats", 'Arti...
# 8   ['All Wikipedia articles written in Australian...
# 9   ['All articles needing additional references',...
# 10  ['All stub articles', "Articles with 'species'...
# 11  ["Articles with 'species' microformats", 'Arti...
# 12  ['All stub articles', "Articles with 'species'...
# 13  ["Articles with 'species' microformats", 'Arti...
# 14  ['Alaudidae stubs', 'All stub articles', "Arti...
# 15  ['Alaudidae', "Articles with 'species' microfo...
# 16  ["Articles with 'species' microformats", 'Arti...
# 17  ["Articles with 'species' microformats", 'Arti...
# 18  ['All stub articles', "Articles with 'species'...
# 19  ["Articles with 'species' microformats", 'Arti...
#
#                                            References  \
# 0   ['http://datazone.birdlife.org/species/factshe...
# 1   ['http://www.worldtwitch.com/fiji.htm', 'http:...
# 2   ['http://www.gpo.gov/fdsys/pkg/FR-2010-12-28/p...
# 3   ['http://datazone.birdlife.org/species/factshe...
# 4   ['http://www.worldbirdnames.org/bow/bulbuls/',...
# 5   ['http://scholar.google.com/scholar?q=%22K%C4%...
# 6   ['http://datazone.birdlife.org/species/factshe...
# 7   ['http://hawaiibirdingtrails.hawaii.gov/bird/k...
# 8   ['http://datazone.birdlife.org/species/factshe...
# 9   ['http://scholar.google.com/scholar?q=%22K%C4%...
# 10  ['http://datazone.birdlife.org/species/factshe...
# 11  ['http://www.birdsinsa.com/birds//cercomelasch...
# 12  ['http://datazone.birdlife.org/species/factshe...
# 13  ['http://www.hbw.com/node/53724', 'http://www....
# 14  ['http://datazone.birdlife.org/species/factshe...
# 15  ['http://members.aol.com/darwinpage/zoo/AOUd.h...
# 16  ['http://datazone.birdlife.org/species/factshe...
# 17  ['http://www.iucnredlist.org/search/details.ph...
# 18  ['http://www.birdsinsa.com/birds/turdussmithi....
# 19  ['http://datazone.birdlife.org/species/factshe...
#
#                                              Wiki URL  \
# 0        https://en.wikipedia.org/wiki/Kadavu_fantail
# 1     https://en.wikipedia.org/wiki/Kadavu_honeyeater
# 2   https://en.wikipedia.org/wiki/Kaempfer%27s_tod...
# 3   https://en.wikipedia.org/wiki/Kaempfer%27s_woo...
# 4     https://en.wikipedia.org/wiki/Kakamega_greenbul
# 5   https://en.wikipedia.org/wiki/K%C4%81k%C4%81wahie
# 6   https://en.wikipedia.org/wiki/Kalahari_scrub_r...
# 7        https://en.wikipedia.org/wiki/Kalij_pheasant
# 8   https://en.wikipedia.org/wiki/Kalkadoon_grasswren
# 9      https://en.wikipedia.org/wiki/K%C4%81ma%CA%BBo
# 10    https://en.wikipedia.org/wiki/Kandt%27s_waxbill
# 11           https://en.wikipedia.org/wiki/Karoo_chat
# 12      https://en.wikipedia.org/wiki/Karoo_eremomela
# 13        https://en.wikipedia.org/wiki/Karoo_korhaan
# 14           https://en.wikipedia.org/wiki/Karoo_lark
# 15                 https://en.wikipedia.org/wiki/Lark
# 16         https://en.wikipedia.org/wiki/Karoo_prinia
# 17    https://en.wikipedia.org/wiki/Karoo_scrub_robin
# 18         https://en.wikipedia.org/wiki/Karoo_thrush
# 19   https://en.wikipedia.org/wiki/Kashmir_flycatcher
#
#                                                 Image        Countries Habitat
# 0   https://upload.wikimedia.org/wikipedia/commons...  Solomon Islands  forest
# 1   https://upload.wikimedia.org/wikipedia/commons...             Fiji  forest
# 2   https://upload.wikimedia.org/wikipedia/commons...    United States  forest
# 3   https://upload.wikimedia.org/wikipedia/commons...           Brazil    None
# 4   https://upload.wikimedia.org/wikipedia/commons...             None  forest
# 5   https://upload.wikimedia.org/wikipedia/commons...             None    None
# 6   https://upload.wikimedia.org/wikipedia/commons...             None    None
# 7   https://upload.wikimedia.org/wikipedia/commons...         Pakistan  forest
# 8   https://upload.wikimedia.org/wikipedia/commons...        Australia    None
# 9   https://upload.wikimedia.org/wikipedia/commons...             None    None
# 10  https://upload.wikimedia.org/wikipedia/commons...             None    None
# 11  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 12  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 13  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 14  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 15  https://upload.wikimedia.org/wikipedia/commons...        Australia    None
# 16  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 17  https://upload.wikimedia.org/wikipedia/commons...     South Africa    None
# 18  https://upload.wikimedia.org/wikipedia/commons...             None    None
# 19  https://upload.wikimedia.org/wikipedia/commons...        Sri Lanka  forest

# %%
#Exporting data to Excel
#Give File name here
file_name = 'bird_K_complete.xlsx'
  
# writing to excel
birds_df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
