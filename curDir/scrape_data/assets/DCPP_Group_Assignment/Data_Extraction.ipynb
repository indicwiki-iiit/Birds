# %%
import pandas as pd
import wikipedia
import numpy as np

# %%
birds = pd.DataFrame(columns=['Name','Conservation status','Kingdom','Phylum','Class','Order','Family', 'Genus', 'Species', 'Binomial Name', 'Synonyms', 'Summary', 'Categories', 'References', 'Wiki URL', 'Image'])
birds
# Out:
# Empty DataFrame
# Columns: [Name, Conservation status, Kingdom, Phylum, Class, Order, Family, Genus, Species, Binomial Name, Synonyms, Summary, Categories, References, Wiki URL, Image]
# Index: []

# %%
def get_conservation_status(df1):
    for i in range(0,len(list(df1.index))):
        if list(df1.index)[i] == 'Conservation status':
            return (list(df1.index)[i+1])
    if 'Conservation status' not in list(df1.index):
        return np.NaN

# %%
def get_kingdom(df1):
    if 'Kingdom:' in list(df1.index):
        return (df1.loc['Kingdom:'][0])
    else:
        return np.NaN

# %%
def get_phylum(df1):
    if 'Phylum:' in list(df1.index):
        return (df1.loc['Phylum:'][0])
    else:
        return np.NaN

# %%
def get_class(df1):
    if 'Class:' in list(df1.index):
        return (df1.loc['Class:'][0])
    else:
        return np.NaN

# %%
def get_order(df1):
    if 'Order:' in list(df1.index):
        return (df1.loc['Order:'][0])
    else:
        return np.NaN

# %%
def get_family(df1):
    if 'Family:' in list(df1.index):
        return (df1.loc['Family:'][0])
    else:
        return np.NaN

# %%
def get_genus(df1):
    if 'Genus:' in list(df1.index):
        return (df1.loc['Genus:'][0])
    else:
        return np.NaN

# %%
def get_species(df1):
    if 'Species:' in list(df1.index):
        return (df1.loc['Species:'][0])
    else:
        return np.NaN

# %%
def get_binomial_name(df1):
    for i in range(0,len(list(df1.index))):
        if list(df1.index)[i] == 'Binomial name':
            return(list(df1.index)[i+1])
    if 'Binomial name' not in list(df1.index):
        return np.NaN

# %%
def get_synonyms(df1):
    for i in range(0,len(list(df1.index))):
        if list(df1.index)[i] == 'Synonyms':
            return(list(df1.index)[i+1])
    if 'Synonyms' not in list(df1.index):
        return np.NaN

# %%
def get_summary(name):
    return(wikipedia.summary(name, sentences=2))

# %%
def get_categories(name):
    categories = wikipedia.page(name)
    return(categories.categories[0:3])

# %%
def get_references(name):
    refs = wikipedia.page(name)
    return(refs.references[0:3])

# %%
def get_url(name):
    url = wikipedia.page(name)
    return(url.url)

# %%
def get_image(name):
    image = wikipedia.page(name)
    return(image.images[0])

# %%
def extract_data(infobox):
    df = pd.DataFrame(infobox)
    df = df.dropna()
    row = [list(df.columns)[0]]
    
    df = df.set_index(list(df.columns)[0])
    
    row.append(get_conservation_status(df))
    row.append(get_kingdom(df))
    row.append(get_phylum(df))
    row.append(get_class(df))
    row.append(get_order(df))
    row.append(get_family(df))
    row.append(get_genus(df))
    row.append(get_species(df))
    row.append(get_binomial_name(df))
    row.append(get_synonyms(df))
    row.append(get_summary(row[0]))
    row.append(get_categories(row[0]))
    row.append(get_references(row[0]))
    row.append(get_url(row[0]))
    row.append(get_image(row[0]))
    
    birds_length = len(birds)
    birds.loc[birds_length] = row

# %%
#Add wiki-links here
pages = ['https://en.wikipedia.org/wiki/Giant_honeyeater','https://en.wikipedia.org/wiki/Giant_hummingbird','https://en.wikipedia.org/wiki/Giant_ibis']

# %%
for i in pages:
    infoboxes = pd.read_html(i, attrs={"class":"infobox biota"})
    if len(infoboxes)==1:
        extract_data(infoboxes[0])
print(birds)
# Out:
#                                           Name  \
# 0                                Gabar goshawk
# 1         (Gabela akalat, Conservation status)
# 2     (Gabela bushshrike, Conservation status)
# 3   (Gabela helmetshrike, Conservation status)
# 4           (Gabon batis, Conservation status)
# ..                                         ...
# 91                            Goeldi's antbird
# 92         (Gola malimbe, Conservation status)
# 93                            Giant honeyeater
# 94                           Giant hummingbird
# 95                                  Giant ibis
#
#                     Conservation status   Kingdom    Phylum Class  \
# 0           Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 1                                   NaN  Animalia  Chordata  Aves
# 2                                   NaN  Animalia  Chordata  Aves
# 3                                   NaN  Animalia  Chordata  Aves
# 4                                   NaN  Animalia  Chordata  Aves
# ..                                  ...       ...       ...   ...
# 91          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 92                                  NaN  Animalia  Chordata  Aves
# 93          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 94          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 95  Critically Endangered (IUCN 3.1)[1]  Animalia  Chordata  Aves
#
#               Order             Family                       Genus  \
# 0   Accipitriformes       Accipitridae   MicronisusG.R. Gray, 1840
# 1     Passeriformes       Muscicapidae                  Sheppardia
# 2     Passeriformes      Malaconotidae                   Laniarius
# 3     Passeriformes           Vangidae                    Prionops
# 4     Passeriformes     Platysteiridae                       Batis
# ..              ...                ...                         ...
# 91    Passeriformes     Thamnophilidae                 Percnostola
# 92    Passeriformes          Ploceidae                    Malimbus
# 93    Passeriformes       Meliphagidae                   Gymnomyza
# 94      Apodiformes        Trochilidae     PatagonaG.R. Gray, 1840
# 95   Pelecaniformes  Threskiornithidae  ThaumatibisElliot, 1877[2]
#
#               Species                               Binomial Name  \
# 0            M. gabar              Micronisus gabar(Daudin, 1800)
# 1           S. gabela               Sheppardia gabela(Rand, 1957)
# 2      L. amboimensis          Laniarius amboimensisMoltoni, 1923
# 3           P. gabela                   Prionops gabelaRand, 1957
# 4           B. minima  Batis minima(Verreaux & Verreaux, 1855)[2]
# ..                ...                                         ...
# 91         P. goeldii          Percnostola goeldiiSnethlage, 1908
# 92       M. ballmanni          Malimbus ballmanniWolters, 1974[2]
# 93  G. brunneirostris        Gymnomyza brunneirostris(Mayr, 1932)
# 94           P. gigas              Patagona gigas(Vieillot, 1824)
# 95        T. gigantea        Thaumatibis gigantea(Oustalet, 1877)
#
#                              Synonyms  \
# 0         Melierax gabar Daudin, 1800
# 1                                 NaN
# 2      Laniarius luehderi amboimensis
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 91                  Myrmeciza goeldii
# 92                                NaN
# 93                                NaN
# 94                                NaN
# 95  Pseudibis gigantea Oustalet, 1877
#
#                                               Summary  \
# 0   The gabar goshawk (Micronisus gabar) is a smal...
# 1   The conservation status of a group of organism...
# 2   The conservation status of a group of organism...
# 3   The conservation status of a group of organism...
# 4   The conservation status of a group of organism...
# ..                                                ...
# 91  Goeldi's antbird (Percnostola goeldii) is a sp...
# 92  The conservation status of a group of organism...
# 93  The giant honeyeater or duetting giant honeyea...
# 94  The giant hummingbird (Patagona gigas) is the ...
# 95  The giant ibis (Thaumatibis gigantea), the onl...
#
#                                            Categories  \
# 0   [Articles with 'species' microformats, Article...
# 1   [All articles containing potentially dated sta...
# 2   [All articles containing potentially dated sta...
# 3   [All articles containing potentially dated sta...
# 4   [All articles containing potentially dated sta...
# ..                                                ...
# 91  [All stub articles, Articles with 'species' mi...
# 92  [All articles containing potentially dated sta...
# 93  [All stub articles, Articles with 'species' mi...
# 94  [Articles with 'species' microformats, Article...
# 95  [Articles with 'species' microformats, Article...
#
#                                            References  \
# 0   [http://www.oiseaux-birds.com/card-gabar-gosha...
# 1   [http://www.inbo.be/content/homepage_en.asp, h...
# 2   [http://www.inbo.be/content/homepage_en.asp, h...
# 3   [http://www.inbo.be/content/homepage_en.asp, h...
# 4   [http://www.inbo.be/content/homepage_en.asp, h...
# ..                                                ...
# 91  [http://www.museum.lsu.edu/Bravo/Publications_...
# 92  [http://www.inbo.be/content/homepage_en.asp, h...
# 93  [http://pubmed.ncbi.nlm.nih.gov/24315868, http...
# 94  [http://ibc.lynxeds.com/sound/giant-hummingbir...
# 95  [http://www.arkive.org/giant-ibis/thaumatibis-...
#
#                                              Wiki URL  \
# 0         https://en.wikipedia.org/wiki/Gabar_goshawk
# 1   https://en.wikipedia.org/wiki/Conservation_status
# 2   https://en.wikipedia.org/wiki/Conservation_status
# 3   https://en.wikipedia.org/wiki/Conservation_status
# 4   https://en.wikipedia.org/wiki/Conservation_status
# ..                                                ...
# 91   https://en.wikipedia.org/wiki/Goeldi%27s_antbird
# 92  https://en.wikipedia.org/wiki/Conservation_status
# 93     https://en.wikipedia.org/wiki/Giant_honeyeater
# 94    https://en.wikipedia.org/wiki/Giant_hummingbird
# 95           https://en.wikipedia.org/wiki/Giant_ibis
#
#                                                 Image
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/commons...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# ..                                                ...
# 91  https://upload.wikimedia.org/wikipedia/commons...
# 92  https://upload.wikimedia.org/wikipedia/commons...
# 93  https://upload.wikimedia.org/wikipedia/commons...
# 94  https://upload.wikimedia.org/wikipedia/commons...
# 95  https://upload.wikimedia.org/wikipedia/commons...
#
# [96 rows x 16 columns]

# %%
#Exporting data to Excel
#Give File name here
file_name = 'Birds_Dataset.xlsx'
  
# writing to excel
birds.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
birds
# Out:
#                                           Name  \
# 0                                Gabar goshawk
# 1         (Gabela akalat, Conservation status)
# 2     (Gabela bushshrike, Conservation status)
# 3   (Gabela helmetshrike, Conservation status)
# 4           (Gabon batis, Conservation status)
# ..                                         ...
# 91                            Goeldi's antbird
# 92         (Gola malimbe, Conservation status)
# 93                            Giant honeyeater
# 94                           Giant hummingbird
# 95                                  Giant ibis
#
#                     Conservation status   Kingdom    Phylum Class  \
# 0           Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 1                                   NaN  Animalia  Chordata  Aves
# 2                                   NaN  Animalia  Chordata  Aves
# 3                                   NaN  Animalia  Chordata  Aves
# 4                                   NaN  Animalia  Chordata  Aves
# ..                                  ...       ...       ...   ...
# 91          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 92                                  NaN  Animalia  Chordata  Aves
# 93          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 94          Least Concern (IUCN 3.1)[1]  Animalia  Chordata  Aves
# 95  Critically Endangered (IUCN 3.1)[1]  Animalia  Chordata  Aves
#
#               Order             Family                       Genus  \
# 0   Accipitriformes       Accipitridae   MicronisusG.R. Gray, 1840
# 1     Passeriformes       Muscicapidae                  Sheppardia
# 2     Passeriformes      Malaconotidae                   Laniarius
# 3     Passeriformes           Vangidae                    Prionops
# 4     Passeriformes     Platysteiridae                       Batis
# ..              ...                ...                         ...
# 91    Passeriformes     Thamnophilidae                 Percnostola
# 92    Passeriformes          Ploceidae                    Malimbus
# 93    Passeriformes       Meliphagidae                   Gymnomyza
# 94      Apodiformes        Trochilidae     PatagonaG.R. Gray, 1840
# 95   Pelecaniformes  Threskiornithidae  ThaumatibisElliot, 1877[2]
#
#               Species                               Binomial Name  \
# 0            M. gabar              Micronisus gabar(Daudin, 1800)
# 1           S. gabela               Sheppardia gabela(Rand, 1957)
# 2      L. amboimensis          Laniarius amboimensisMoltoni, 1923
# 3           P. gabela                   Prionops gabelaRand, 1957
# 4           B. minima  Batis minima(Verreaux & Verreaux, 1855)[2]
# ..                ...                                         ...
# 91         P. goeldii          Percnostola goeldiiSnethlage, 1908
# 92       M. ballmanni          Malimbus ballmanniWolters, 1974[2]
# 93  G. brunneirostris        Gymnomyza brunneirostris(Mayr, 1932)
# 94           P. gigas              Patagona gigas(Vieillot, 1824)
# 95        T. gigantea        Thaumatibis gigantea(Oustalet, 1877)
#
#                              Synonyms  \
# 0         Melierax gabar Daudin, 1800
# 1                                 NaN
# 2      Laniarius luehderi amboimensis
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 91                  Myrmeciza goeldii
# 92                                NaN
# 93                                NaN
# 94                                NaN
# 95  Pseudibis gigantea Oustalet, 1877
#
#                                               Summary  \
# 0   The gabar goshawk (Micronisus gabar) is a smal...
# 1   The conservation status of a group of organism...
# 2   The conservation status of a group of organism...
# 3   The conservation status of a group of organism...
# 4   The conservation status of a group of organism...
# ..                                                ...
# 91  Goeldi's antbird (Percnostola goeldii) is a sp...
# 92  The conservation status of a group of organism...
# 93  The giant honeyeater or duetting giant honeyea...
# 94  The giant hummingbird (Patagona gigas) is the ...
# 95  The giant ibis (Thaumatibis gigantea), the onl...
#
#                                            Categories  \
# 0   [Articles with 'species' microformats, Article...
# 1   [All articles containing potentially dated sta...
# 2   [All articles containing potentially dated sta...
# 3   [All articles containing potentially dated sta...
# 4   [All articles containing potentially dated sta...
# ..                                                ...
# 91  [All stub articles, Articles with 'species' mi...
# 92  [All articles containing potentially dated sta...
# 93  [All stub articles, Articles with 'species' mi...
# 94  [Articles with 'species' microformats, Article...
# 95  [Articles with 'species' microformats, Article...
#
#                                            References  \
# 0   [http://www.oiseaux-birds.com/card-gabar-gosha...
# 1   [http://www.inbo.be/content/homepage_en.asp, h...
# 2   [http://www.inbo.be/content/homepage_en.asp, h...
# 3   [http://www.inbo.be/content/homepage_en.asp, h...
# 4   [http://www.inbo.be/content/homepage_en.asp, h...
# ..                                                ...
# 91  [http://www.museum.lsu.edu/Bravo/Publications_...
# 92  [http://www.inbo.be/content/homepage_en.asp, h...
# 93  [http://pubmed.ncbi.nlm.nih.gov/24315868, http...
# 94  [http://ibc.lynxeds.com/sound/giant-hummingbir...
# 95  [http://www.arkive.org/giant-ibis/thaumatibis-...
#
#                                              Wiki URL  \
# 0         https://en.wikipedia.org/wiki/Gabar_goshawk
# 1   https://en.wikipedia.org/wiki/Conservation_status
# 2   https://en.wikipedia.org/wiki/Conservation_status
# 3   https://en.wikipedia.org/wiki/Conservation_status
# 4   https://en.wikipedia.org/wiki/Conservation_status
# ..                                                ...
# 91   https://en.wikipedia.org/wiki/Goeldi%27s_antbird
# 92  https://en.wikipedia.org/wiki/Conservation_status
# 93     https://en.wikipedia.org/wiki/Giant_honeyeater
# 94    https://en.wikipedia.org/wiki/Giant_hummingbird
# 95           https://en.wikipedia.org/wiki/Giant_ibis
#
#                                                 Image
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/commons...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# ..                                                ...
# 91  https://upload.wikimedia.org/wikipedia/commons...
# 92  https://upload.wikimedia.org/wikipedia/commons...
# 93  https://upload.wikimedia.org/wikipedia/commons...
# 94  https://upload.wikimedia.org/wikipedia/commons...
# 95  https://upload.wikimedia.org/wikipedia/commons...
#
# [96 rows x 16 columns]
